# %% [markdown]
# <a href="https://colab.research.google.com/github/Mehmetal/usefulscripts/blob/main/3d_Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

k=np.array([[0.75284376, 0.75748293, 0.73633988, 0.73176226, 0.76268683, 0.74686129,
  0.76296143, 0.75240902, 0.75342207, 0.75365283],
 [0.51190036, 0.56475179, 0.61431693, 0.68989786, 0.72675017, 0.77680702,
  0.82417671, 0.82884738, 0.81055519, 0.77040588],
 [0.51190417, 0.5828996,  0.66073733, 0.7522656,  0.85904226, 0.88628167,
  0.91703388, 0.86533386, 0.83976912, 0.77105619],
 [0.51189502, 0.60456586, 0.75522131, 0.89844852, 0.95378369, 0.97375312,
  0.94337321, 0.89369619, 0.85297721, 0.77173807],
 [0.51190236, 0.87589214, 0.94715233, 0.99573855, 1.0372154,  1.00976369,
  0.98575,    0.90869445, 0.83145893, 0.7776131 ],
 [0.51189405, 0.972559,   1.01102283, 1.05013121, 1.08275426, 1.02298605,
  0.96644524, 0.92251798, 0.81977845, 0.78408893],
 [0.51187724, 1.030219,   1.03241721, 1.05847855, 1.0758175,  1.02751912,
  0.98704414, 0.89924731, 0.84130188, 0.78592198],
 [0.51189188, 0.87048724, 0.9791376,  1.03787226, 1.05934845, 1.04245276,
  1.00015367, 0.8984775,  0.85382845, 0.77492305],
 [0.51190452, 0.88092512, 1.02723214, 1.07237214, 1.05937905, 1.03560381,
  0.98036836, 0.90588807, 0.82989638, 0.77231381],
 [0.51188398, 0.80470038, 0.99659595, 1.06723352, 1.07968445, 1.04951786,
  0.98162512, 0.9039739,  0.82877667, 0.76905655]])
print("min:")
print(np.min(k))
print("min index:")
print(np.where(k==np.min(k)))
print("max")
print(np.max(k))
print("max index:")
print(np.where(k==np.max(k)))
X = np.arange(0,1,1/10)
Y = np.arange(0,1,1/10)
X, Y = np.meshgrid(X, Y)
fig = plt.figure(figsize=(15,10))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, k, rstride=1, cstride=1, cmap='coolwarm', linewidth=0, antialiased=False)
#ax.set_zlim(0, 1.01)
plt.xlabel(r'$\alpha$')
plt.ylabel(r'$\epsilon$')
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.savefig("3d graph")
plt.show()
# Out:
# min:
# 0.51187724
# min index:
# (array([6]), array([0]))
# max
# 1.08275426
# max index:
# (array([5]), array([4]))
